# %% [markdown]
# MANIPULATION OF COLUMNS AND ROWS
# * Changing the name of each column
# * Changing the row name
# * Using apply,map,applymap,replace
# * Adding and removing rows and columns
# * Filtering out the data as per the need and showing only required columns

# %%
import pandas as pd
df= pd.read_csv("E:\LIT CONTENT\ML PROJECT\Pandas tutorial\data2019\dataframe.csv",index_col='Respondent')
schema_df=pd.read_csv("E:\LIT CONTENT\ML PROJECT\Pandas tutorial\data2019\survey_results_schema.csv",index_col='Column')
#to sort data based on index
schema_df.sort_index(ascending = True, inplace=True)
pd.set_option("display.max_columns", 85)
pd.set_option("display.max_rows",85)
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
#changing the column name
#df.columns=['a','b','c','d'']
#df.columns = [x.Upper() for x in df.columns]
#for changing the names only in specific columns

#df.rename(columns={'first_name':'first','last_name:''last'})
#use the method loc to change data not direct calling or accessing of data
#

# %%
#manipulation in rows
df.loc[:2]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df.apply(len,axis = 'columns')
# Out:
# Respondent
# 1        84
# 2        84
# 3        84
# 4        84
# 5        84
#          ..
# 88377    84
# 88601    84
# 88802    84
# 88816    84
# 88863    84
# Length: 88883, dtype: int64

# %%
df.rename(columns={"ConvertedComp":"SalaryUSD"}, inplace = True)
df['Hobbyist']=df['Hobbyist'].map({'Yes':True, 'No':False})

# %%
df.sort_values(by=['Country','SalaryUSD'],ascending = [False,True], inplace = True)
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 47247       I am not primarily a developer, but I write co...     False
# 6492                           I am a developer by profession      True
# 30743                          I am a developer by profession      True
# 35092                          I am a developer by profession      True
# 84155       I am not primarily a developer, but I write co...      True
# ...                                                       ...       ...
# 88062                                                     NaN     False
# 88076                                                     NaN     False
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.nsmallest(5000, 'SalaryUSD')
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 75010       I am a developer by profession     False
# 82369       I am a developer by profession     False
# 280         I am a developer by profession      True
# 4073        I am a developer by profession      True
# 4770        I am a developer by profession      True
# ...                                    ...       ...
# 65242       I am a developer by profession      True
# 77417       I am a developer by profession      True
# 78521       I am a developer by profession      True
# 79329       I am a developer by profession      True
# 81180       I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 75010                                                   Never
# 82369                                                   Never
# 280                                   Less than once per year
# ...

# %%
filt=(df['Country']=='India')
dfIndia=df.loc[filt]
dfIndia.sort_values(by='SalaryUSD',ascending = False,inplace=True)
dfIndia.head(30)
# Out:
# C:\Users\Samriddh\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                    MainBranch  Hobbyist  \
# Respondent
# 72732       I am not primarily a developer, but I write co...     False
# 28243                          I am a developer by profession      True
# 22013                          I am a developer by profession      True
# 80923                          I am a developer by profession      True
# 78265                          I am a developer by profession      True
# 52561                          I am a developer by profession      True
# 16793                          I am a developer by profession      True
# ...

# %%
dfIndia.iloc[0:50 , [6,30,33,45,40,14,42,43,44]]
# Out:
#                    Student  SalaryUSD  \
# Respondent
# 72732       Yes, full-time  2000000.0
# 28243                   No  2000000.0
# 22013                   No  2000000.0
# 80923                  NaN  1000000.0
# 78265       Yes, full-time  1000000.0
# 52561                   No  1000000.0
# 16793                   No  1000000.0
# 53840                   No   962678.0
# 64181                   No   671652.0
# 76711                   No   654864.0
# 56055                   No   621276.0
# 32536                   No   601690.0
# 42042                   No   587700.0
# 76048                   No   559700.0
# 81419                   No   554112.0
# 9849        Yes, full-time   554112.0
# 86603                   No   537324.0
# 81272                   No   503736.0
# 44521                   No   503736.0
# 23683       Yes, full-time   503736.0
# 31079                   No   486948.0
# 67804                   No   470160.0
# 47728                   No   470160.0
# ...

# %%
dfIndia.median()
# Out:
# Hobbyist            1.0
# CompTotal      405000.0
# SalaryUSD       10080.0
# WorkWeekHrs        42.0
# CodeRevHrs          5.0
# Age                25.0
# dtype: float64
