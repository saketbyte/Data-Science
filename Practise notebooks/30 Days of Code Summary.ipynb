# %% [markdown]
# # Some good playlists/blogs  to follow for learning python.
# 1. Programiz(Articles and Videos): https://www.programiz.com/python-programming
# 2. Corey Schafer(YT Playlist): https://www.youtube.com/playlist?list=PL-osiE80TeTskrapNbzXhwoFUiLCjGgY7
# 3. Misc. Python: https://www.youtube.com/playlist?list=PLu0W_9lII9aiJWQ7VhY712fuimEpQZYp4
# 4. Intro Course: https://www.udacity.com/course/introduction-to-python--ud1110
# 5. Dphi Course: https://dphi.tech/courses/introduction-to-python-basics-for-data-science

# %% [markdown]
# # Ways of Input and output in Python

# %%
inPut = input()
inPut = int(input()) #to accept integer value, type conversion.

# input via readline method
n = stdin.readline()
# array input similar method
arr = [int(x) for x in stdin.readline().split()]
"""This is known as list comprehension to take inputs. 
    Split function will split on the basis of what 
    separator we provide. Another method to take inputs 
    in one variable is given as.
    """

#int array
def get_ints():
    return list(map(int, sys.stdin.readline().strip().split()))
Arr = get_ints()

#string input

def get_string():
    return sys.stdin.readline().strip()
 
string = get_string()



print('The inputted string is:', inputString)

# You would not wanna miss thiss - https://stackoverflow.com/questions/43166038/how-to-create-a-2d-list-from-a-input-data

# %%
#OUTPUTS

#simple way
q = 459
p = 0.098
print(q, p, p * q) 
print(q, p, p * q, sep = ",", end = "\n") 


""" The arguments of the print function are as follows - 
1. sep = "\n" ,  it can be space, coma or any group of characters.
   By default it is new line character.
2. objects - object to the printed. * indicates that there may be more than one object
3. end - end is printed at last
4. file - must be an object with write(string) method. If omitted it, sys.stdout will be used which prints objects on the screen.
5. flush - If True, the stream is forcibly flushed. Default value: False
We can concatenate only string outputs in print function, so if we wish to print other data type
variables then it is needed to convert them to strings, str(n) .
Using string modulo operator but it is very obsolete now.
Using the dot format function
"""
#dot format
capital_country = {"United States" : "Washington", 
                   "US" : "Washington", 
                   "Canada" : "Ottawa",
                   "Germany": "Berlin",
                   "France" : "Paris",
                   "England" : "London",
                   "UK" : "London",
                   "Switzerland" : "Bern",
                   "Austria" : "Vienna",
                   "Netherlands" : "Amsterdam"}

print("Countries and their capitals:")
for c in capital_country:
    print("{country}: {capital}".format(country=c, capital=capital_country[c]))

    
"""Refer this for more - https://www.programiz.com/python-programming/methods/built-in/print"""

# %% [markdown]
# # Data types in python
#
# Built-in Data Types
# In programming, data type is an important concept.
#
# Variables can store data of different types, and different types can do different things.
#
# Python has the following data types built-in by default, in these categories:
#
# Text Type:	str
#
#
# Numeric Types:	int, float, complex
#
#
# Sequence Types:	list, tuple, range
#
#
# Mapping Type:	dict
#
#
# Set Types:	set, frozenset
#
#
# Boolean Type:	bool
#
#
# Binary Types:	bytes, bytearray, memoryview

# %%
x = 5
print(type(x)) # to get the type of any variable

# Read this for more - https://www.w3schools.com/python/python_datatypes.asp

# %% [markdown]
# # Operators
# #### Again, https://www.w3schools.com/python/python_operators.asp is a really good page to study in crisp and quick way.
#
# The operators are in the following groups:
#
# Arithmetic operators
#
#
# Assignment operators
#
#
# Comparison operators
#
#
# Logical operators
#
#
# Identity operators
#
#
# Membership operators
#
#
# Bitwise operators
#
#
#
# # Conditional statements in python
# https://www.w3schools.com/python/python_conditions.asp
#
# I am questioning why do I even need to make this nb, everything is there on w3schools.
#
# # LoOps :p
# https://www.w3schools.com/python/python_for_loops.asp
#
#
#
# About the range function-
#
# * range(start, stop, step)
#
#
# Arguments :
#
#
# Parameter
#
#
# start	Optional. An integer number specifying at which position to
#
#
# start. Default is 0
#
#
# stop	Required. An integer number specifying at which position to stop (not included).
#
#
# step	Optional. An integer number specifying the incrementation. Default is 1
#
#
# # There are four collection data types in the Python programming language
#
#
# List is a collection which is ordered and changeable. Allows duplicate members. https://www.w3schools.com/python/python_lists.asp
#
#
#
# Tuple is a collection which is ordered and unchangeable. Allows duplicate members.https://www.w3schools.com/python/python_tuples.asp
#
#
# Set is a collection which is unordered and unindexed. No duplicate members. https://www.w3schools.com/python/python_sets.asp
#
#
# Dictionary is a collection which is ordered* and changeable. No duplicate members. https://www.w3schools.com/python/python_dictionaries.asp

# %% [markdown]
# # OOP yay !! In love with OOP since class 12 ! <3
#
# ## Object oriented programming in Python

# %%
# Q1 What is an object ?
x = 1
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# Pretty much everything in python too, is a class which includes -  all data types, functions, and different structures as well.
#
# Class defines the way an object can behave in the programme. An object is a virtual realisation of the abstract/blueprint idea defined under the class.

# %%
# Q2 Methods: Functions of a class

string  = "Wassup ?"

print(string.upper())
# Out:
# WASSUP ?

# %% [markdown]
# These methods are based on the type of class they are a part of, which perform a certain kind of function on our object or data. These are an integral part of our class definition and they are used on an object by "." the dot operator.
#
# So if our class is of type dog, it will contain the data that stores some values, methods to tell the functionality of the instance or object we create.

# %%
# class is a keyword used before class name.


class Dog:
    
    # We have a special method called CONSTRUCTOR. It is called everytime an object is created.
    # Everytime we create a dog object, we will pass a reference to which object it was called on and it will initialise 
    # the attributes/data as in the line self.name = Name and the print it. It assosciates the functions, data members 
    # with the object to which it is dotted.
    
    def __init__(self, Name, Age):
        self.name = Name
        self.age = Age
       # print("name associated with object : " + self.name)
       # print("Name as the constructor argument(local) : "+Name)
        
    # This is a method to provide some functionality
    
    def bark(self):
        print("Bhauw !")
        
# self invisibly passes the reference to the current object which is calling our method. It basically tells
# which dog we are accessing at the moment.



# NOTE THAT: If you do not pass the "self" word in functions, you will get an error : 
#                get_age() takes 0 positional arguments byt 1 was given
# which means to say that since you did not put any arguments in the function definition [def get_age(*nothing*):]
# according to this definition, your function is not supposed to take any arguments, but 1 was given eh ?
# That one argument is a positional argument which refrences the current object which is calling our method of the same class
# to which the object and the function belong. It is happening in the background.
                            
    # This is another method to return some value called getter method in general
    def get_age(self):
        return self.age
    
    #This is a setter method
    def set_age(self,aGe):
        self.age = aGe
        
        
# d is an object of class Dog
d1 = Dog("Cheems", 2)
d2 = Dog("Memes",100)

#executing the functionality of class dog through the object d1 and d2.

d1.bark()
print(d1.name)
print(d1.get_age())
d1.set_age(2.3)
print("After change"+ str(d1.get_age()))
 
print()

d2.bark()
print(d2.name)
print(d2.get_age())
# Out:
# Bhauw !
# Cheems
# 2
# After change2.3
#
# Bhauw !
# Memes
# 100

# %%
#Another example with multiple classes interacting with each others data members.


class Student:
    def __init__(self, name, age, grade):
        self.name = name
        self.age = age
        self.grade = grade
        
    def get_grade(self):
        return self.grade
    
class Course:
    def __init__(self,name, max_students):
        self.name = name
        self.max_students = max_students
        self.students = []
        
    def add_student(self, student):
        if len(self.students) < self.max_students:
            self.students.append(student)
            return True
        else:
            print("Seats full")
            return False
    
    def get_average_grade(self):
        value =0
        for student in self.students:
            value += student.get_grade()
            return value/ len(self.students)
    
    
s1 = Student("Sam",21,92)
s2 = Student("Lohit", 21, 90)

course = Course("OS",1)

course.add_student(s1)
course.add_student(s2)

print(course.get_average_grade())
# Out:
# Seats full
# 92.0

# %% [markdown]
# #### Inheritance
#
# Inheritance allows us to define a class that inherits all the methods and properties from another class.
#
# Parent class is the class being inherited from, also called base class.
#
# Child class is the class that inherits from another class, also called derived class.
#
# * Advantages:
#
# Code reusability- we do not have to write the same code again and again, we can just inherit the properties we need in a child class.
#
# It represents a real world relationship between parent class and child class.
#
# It is transitive in nature. If a child class inherits properties from a parent class, then all other sub-classes of the child class will also inherit the properties of the parent class.

# %%
class Pet:
    
    def __init__(self,name,age):
        self.name = name
        self.age = age
        
    def show(self):
        print(f"I am {self.name} and I am {self.age} years old")
    
    def speak(self):
        print("Pet speaks")
        

class Cat(Pet):
    
    
    def __init__(self,name, age, color):
        
        #explicitly calling the constructor of the parent class which will refer to our current object only.
        super().__init__(name,age) 
        self.color = color
    
    def speak(self):
        print("Meow "+self.color)
        
        
        
        
class Dog(Pet):
    def speak(self):
        print("Bark")
        
        

#instance of pet class as parent class
p =  Pet("Tim", 19)
p.show()
p.speak()

#instance of Cat and dog ie children class, note that in the output when we called objects of child classes, constructor of
# parent class was called again, because these classes inherit the properties of parent class like the data members.

# Note that in cases like-
#1. The child class shares a function with same name as in parent class, the function of parent class is
# executed for the parent class object only.

#2. However, if there exists such a child class which does not have a function with name foo() otherwise present in parent class, 
#but a call is made through the object of child class object to foo(), then parent class foo() will provide for it. Here - 

class Fish(Pet):
    pass




c = Cat("Billi", 2,"Whaite")
c.show()

d = Dog("cheems",1)
d.show()


c.speak()
d.speak()

# Missing functionality provided by parent class
f = Fish("Gold", 10)
f.speak()
# Out:
# I am Tim and I am 19 years old
# Pet speaks
# I am Billi and I am 2 years old
# I am cheems and I am 1 years old
# MeowWhaite
# Bark
# Pet speaks

# %% [markdown]
# #### Class attributes, static methods and class methods

# %%
# everytime we define and attribute, we used the word self, referimng to the current instance we are using.
# class attributes refer to the class and not an object or instance.

class Person:
    n_people = 0
    def __init__(self,name):
        self.name = name
        Person.add_person()
        
        
    @classmethod 
    def n_peop(cls):
        return cls.n_people
    
    @classmethod
    def add_person(cls):
        cls.n_people +=1
        
        
    
p1 = Person("tim")
# print(p1.n_people)
p2 = Person("sim")



# Even though it was not changed with respect to an object, but change for the class attribute is a change 
#for all objects as well

print(p2.n_people)


#using class methods,using "@" they act on the class itself, and we use cls instead of self
print(Person.n_peop()) # I dont need an object to call this function.
# Out:
# 2
# 2

# %%
#static methods - stay same. Do something but dont change anything.
#because they do not have access to any data member.

#sometimes we need structure in our program whose file is used at some other place as well.


class Maths:
    @staticmethod
    def add(x):
        return x+5
    def mul(x):
        return x*5
    
print(Maths.add(5))
print(Maths.mul(5))
# Out:
# 10
# 25

# %%
#Concept of Abstract class



"""
Abstraction is a process of hiding the implementation details and showing only functionality to the user.

Another way, it shows only essential things to the user and hides the internal details, for example, 
sending SMS where you type the text and send the message.
You don't know the internal processing about the message delivery.

Abstraction lets you focus on what the object does instead of how it does it.

Ways to achieve Abstraction
There are two ways to achieve abstraction in java

Abstract class (0 to 100%)
Interface (100%)

A class which is declared as abstract is known as an abstract class. 
It can have abstract and non-abstract methods.

* It needs to be extended and its method implemented.*

* It cannot be instantiated.*

"""



#Question


"""

Given a Book class and a Solution class, write a MyBook class that does the following:

Inherits from Book
Has a parameterized constructor taking these  parameters:
string 
string 
int 
Implements the Book class' abstract display() method so it prints these  lines:
Title, a space, and then the current instance's .
Author, a space, and then the current instance's .
Price , a space, and then the current instance's .
Note: Because these classes are being written in the same file, you must not use an access modifier (e.g.: ) when declaring MyBook or your code will not execute.




"""
#Answer




from abc import ABCMeta, abstractmethod
class Book(object, metaclass=ABCMeta):
    def __init__(self,title,author):
        self.title=title
        self.author=author   
    @abstractmethod
    def display(): pass

#Write MyBook class

class MyBook(Book):
    def __init__(self, title, author, price):
        self.title =title
        self.author = author
        self.price = price
        
    def display(self):
        print("Title: "+title)
        print("Author: "+author)
        print("Price: "+str(price))
        
        
        

title=input()
author=input()
price=int(input())
new_novel=MyBook(title,author,price)
new_novel.display()


# Abstract classes :
"""
Abstract classes are more of a concept based things which provides some structure or overview of the real classes to be made
later.

This is an essential feature of object-oriented programming. In essense, it's the separation between what a class does 
and how it's accomplished.

One real world example of this concept is a snack machine, where you give the machine money, make a selection, and the 
machine dispenses the snack. The only thing that matters is what the machine does (i.e.: dispenses the selected snack); 
you can easily buy a snack from any number of snack machines without knowing how the machine's internals are designed
(i.e.: the implementation details).


Abstract Class
This type of class can have abstract methods as well as defined methods, but it cannot be instantiated 
(meaning you cannot create a new instance of it). To use an abstract class, you must create and instantiate a subclass 
that extends the abstract class. Any abstract methods declared in an abstract class must be implemented by its subclasses 
(unless the subclass is also abstract).

"""

# %% [markdown]
# # Scope
#
# The concept of scope rules how variables and names are looked up in your code. It determines the visibility of a variable
# within the code. The scope of a name or variable depends on the place in your code where you create that variable.
# The Python scope concept is generally presented using a rule known as the LEGB rule.
#
# LEGB = Local, Enclosing, Global, and Built-in scopes. This summarizes not only the
# Python scope levels but also the sequence of steps that Python follows when resolving names in a program
#
#
# For example, if you assign a value to a name inside a function, then that name will have a local Python scope.
# In contrast, if you assign a value to a name outside of all functions—say, at the top level of a module—then that name
# will have a global Python scope.
#
#
#
# * Website to refer : https://www.datacamp.com/community/tutorials/scope-of-variables-python
#
# #### Local Scope
#
#
# Local (or function) scope is the code block or body of any Python function or lambda expression.
# This Python scope contains the names that you define inside the function. These names will only be
# visible from the code of the function. It’s created at function call, not at function definition, so you’ll
# have as many different local scopes as function calls. This is true even if you call the same function multiple times,
# or recursively. Each call will result in a new local scope being created.
#
#
# #### Enclosing
# Enclosing (or nonlocal) scope is a special scope that only exists for nested functions. If the local scope is
# an inner or nested function, then the enclosing scope is the scope of the outer or enclosing function.
# This scope contains the names that you define in the enclosing function. The names in the enclosing scope are visible from
# the code of the inner and enclosing functions.
#
# #### Global
# Global (or module) scope is the top-most scope in a Python program, script, or module. This Python scope contains
# all of the names that you define at the top level of a program or a module. Names in this Python scope are visible
# from everywhere in your code.
#
#
#
# #### Built in scope
# Built-in scope is a special Python scope that’s created or loaded whenever you run a script or open an interactive session.
# This scope contains names such as keywords, functions, exceptions, and other attributes that are built into Python.
# Names in this Python scope are also available from everywhere in your code. It’s automatically loaded by Python when you
# run a program or script.
#
#
#
# * For c++ lovers this is gooood and simple :  https://edux.pjwstk.edu.pl/mat/260/lec/PRG2CPP_files/node33.html

# %% [markdown]
# # LinkedLists
#
# A singly linked list is a data structure having a list of elements where each element has a reference pointing to the next element in the list. Its elements are generally referred to as nodes; each node has a data field containing a data value and a next field pointing to the next element in the list (or null if it is the last element in the list).
#
# * || [Value] ||>>|| [Value] ||>>|| [Value] ||
#   || [_ptr_] ||>>|| [_ptr_] ||>>|| [_ptr_] ||>>>NONE
#
# We need to create 2 classes here, class LinkedList is to provide the functionality of LinkedList data structure and
# class Node is to provide the functionality for the implementation of Linked List itself.
#
# A node has two data members - value and pointer to the next node.
# The starting node is needed to access the whole list and is usually called a head node or start node. We traverse the whole list one by one and perform different actions.

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None 
class LinkedList: 
    def display(self,head):
        current = head
        while current:
            print(current.data,end=' ')
            current = current.next

    def insert(self,head,data):
    #Complete this method
        node = Node(data)
        if head==None :
            return node
        else :
            currentNode=head;
            while currentNode.next != None :
                currentNode=currentNode.next;
            currentNode.next=node
            return head

mylist= LinkedList()
T=int(input())
head=None
for i in range(T):
    data=int(input())
    head=mylist.insert(head,data)    
mylist.display(head);

# %% [markdown]
# # Exception handling
#
# * What is Exception?
# An exception is an event, which occurs during the execution of a program that disrupts the normal flow of the program's instructions. In general, when a Python script encounters a situation that it cannot cope with, it raises an exception. An exception is a Python object that represents an error.
# <b> Handling exceptions saves our programme from termination at the
# immediate point of exception, thus, only the exception thing will not work properly, rest of the programme exectutes as it is.</b>
#
#
# Python has several classes for exception handling
#
#
# * Handling an exception
#
# If you have some suspicious code that may raise an exception, you can defend your program by placing the suspicious code in a <b>try</b> : block.
#
# The try: block, include an <b>except</b>: statement, followed by a block of code which handles the problem as elegantly as possible.
#
# The <b>finally</b> block is used when we want to execute some piece of code for sure, irrespective of the fact that an exception is raised or not at all.
#
# The <b>else</b> An else block is used to contain the code which should be executed if there are no any exceptions raised.
#
# The <b>raise Exception("Description")</b> is used when some statements outside the try except block are there which we would
# require to be checked for exception, but occur only when called for execution, not during interpretation process.
#
#
# Error and exceptions both are bugs in the programmed but-
# Errors can't be handled whereas Exception can be handled during run time.
#
# It is a good practise to be specific while catching exceptions and allowing further programme to run as usual.
#
# * Reference video - https://youtu.be/NIWwJbo-9_8
# * Reference article - https://www.tutorialspoint.com/python/python_exceptions.htm

# %%
# We put the most specific expected exceptions at the beginning and then go more general and broader as we go down the 
#if else ladder. 
class Odd:
    
    def check(self,a):
        if(a%2!=0):
            raise Exception
        else:
            print("Yay!")

try:
    obj = Odd()
    obj.check(5)
    print("This is the code where you expect an exception to occur sometime.")
    
except IOError as e:                     #only if there is an IO error, just catch that or hold it and throw as a warning.
    print('Input output error!')
except Exception as e:                   #only if there is an IO error, just catch that or hold it and throw as a warning.
    print('General error here passing an odd number maybe')
else:
    print("No exceptions were raised this time !")
finally:
    print("Executing Finally regardless of errors...")

    

print('End of program')
# Out:
# General error here passing an odd number maybe
# Executing Finally regardless of errors...
# End of program

# %% [markdown]
# # Queues and Stacks -
#
#
# Visualize stack as a pile of books and Queue as a row of people waiting at the billing desk.
#
# Stack - Last in first out.
#
# Queue  - First in first out.
#
# Queues and Stacks in Python are implemented using lists.
#
#
# * To implement a stack, therefore, we need two simple operations:
#
# push - adds an element to the top of the stack:
#
# pop - removes the element at the top of the stack:
#
#
# * To implement a queue, therefore, we need two simple operations:
#
# enqueue - adds an element to the end of the queue:
#
#
# dequeue - removes the element at the beginning of the queue:
#
# If your code needed a stack and you provide a List, there's nothing stopping a programmer from calling insert, remove or other list functions that will affect the order of your stack! This fundamentally ruins the point of defining a stack, as it no longer functions the way it should.
#
# There are times when we'd like to ensure that only valid operations can be performed on our data.
#
# We can create classes that only exposes the necessary methods for each data structure.
#
# * Credits : https://stackabuse.com/stacks-and-queues-in-python/

# %%
# A simple class stack that only allows pop and push operations
class Stack:

    def __init__(self):
        self.stack = []

    def pop(self):
        if len(self.stack) < 1:
            return None
        return self.stack.pop()

    def push(self, item):
        self.stack.append(item)

    def size(self):
        return len(self.stack)

# And a queue that only has enqueue and dequeue operations
class Queue:

    def __init__(self):
        self.queue = []

    def enqueue(self, item):
        self.queue.append(item)

    def dequeue(self):
        if len(self.queue) < 1:
            return None
        return self.queue.pop(0)

    def size(self):
        return len(self.queue) 

#Credits : https://stackabuse.com/stacks-and-queues-in-python/

# %% [markdown]
# # Interfaces and its difference from Abstract classes
#
# Abstraction: Hiding the internal implementation of the feature and only showing the functionality to the users. i.e. what it works (showing), how it works (hiding). Both abstract class and interface are used for abstraction.
#
# * Interface
#
# Recall that abstraction is the separation between what something does and how it's accomplished. An interface is a collection of abstract methods and constants that form a common set of base rules/specifications for those classes that implement it. Much like an abstract class, an interface cannot be instantiated and must be implemented by a class.
#
# https://www.geeksforgeeks.org/difference-between-abstract-class-and-interface-in-java/

# %% [markdown]
# ## Sorting !
#
# Sorting algo - Best, Avg and Worst case complexities
# 1. Quick Sort - O(log n) , O(log n) O(n^2)
# 2. Merge Sort - O(log n) , O(log n), O(log n)
# 3. Bubble Sort - O(n2) , O(n2), O(n2)
# 4. Selection Sort - O(n2),O (n2),O(n2)
#
# For the challenge - [Video](https://www.youtube.com/watch?v=lyZQPjUT5B4) , [Blog](https://en.wikipedia.org/wiki/Bubble_sort#:~:text=Bubble%20sort%2C%20sometimes%20referred%20to,are%20in%20the%20wrong%20order.&text=The%20algorithm%2C%20which%20is%20a,the%20top%20of%20the%20list)
#
#
# There is so much to write here, so it is better to write nothing and you bookmark this topic to studey in depth later.
